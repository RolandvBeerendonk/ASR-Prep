# %%
if __name__ == "__main__":
    # %run ASRmodel.ipynb
    # %run ASRView.ipynb
    # %run ASRcontroller.ipynb
    
    model = ASRModel()
    view = ASRView()
    controller = ASRController(model, view)

    controller.add_stock("AAPL", "Technology", "Equity", 10, 150)
    controller.add_stock("MSFT", "Technology", "Equity", 5, 280)
    controller.add_stock("JNJ", "Healthcare", "Equity", 8, 160)

    controller.load_data("2020-01-01")
    controller.show_historical_prices(tickers=["AAPL", "MSFT"],individual_graph=True)
    print(controller.show_current_price("AAPL"))
    print(controller.show_portfolio_value())
    print(controller.show_portfolio_weight('class'))

    controller.show_portfolio_circle('class')
    controller.show_portfolio_summary('class')
    controller.show_var_plot()
    controller.show_correlation_plot()
    controller.show_cumulative_return()

    controller.simulate_and_plot_stock_paths(n_plot_paths=1000)
    controller.simulate_and_plot_portfolio_paths(mode='quantiles', n_plot_paths=1000)


    controller.show_var_and_cvar(confidence_level=0.05)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 198.14999389648438
# Ticker
# AAPL    1981.499939
# JNJ     1213.839966
# MSFT    1942.250061
# Name: Market Value, dtype: object
# Asset Class
# Equity    1.0
# Name: Market Value, dtype: object
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/908624174.py:25: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(self.data[ticker]['Close'].iloc[-1])
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/908624174.py:25: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(self.data[ticker]['Close'].iloc[-1])
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/908624174.py:25: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(self.data[ticker]['Close'].iloc[-1])
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/1236074180.py:112: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   grouped.plot(kind='pie', autopct='%1.1f%%', startangle=90)
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/908624174.py:25: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(self.data[ticker]['Close'].iloc[-1])
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/1236074180.py:83: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p = purchase_values[i]
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/1236074180.py:84: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   inc = incomes[i]
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/1236074180.py:85: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   total = total_values[i]
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/1236074180.py:121: FutureWarning: 'w' is deprecated and will be removed in a future version, please use 'W' instead.
#   weekly_var[col]= daily_returns[col].resample('w').apply(lambda x: x.quantile(confidence))
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/1236074180.py:121: FutureWarning: 'w' is deprecated and will be removed in a future version, please use 'W' instead.
#   weekly_var[col]= daily_returns[col].resample('w').apply(lambda x: x.quantile(confidence))
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/1236074180.py:121: FutureWarning: 'w' is deprecated and will be removed in a future version, please use 'W' instead.
#   weekly_var[col]= daily_returns[col].resample('w').apply(lambda x: x.quantile(confidence))
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/908624174.py:25: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(self.data[ticker]['Close'].iloc[-1])
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/908624174.py:25: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(self.data[ticker]['Close'].iloc[-1])
# /var/folders/yj/fx1y1b115ngbgq3gmm76hs4c0000gp/T/ipykernel_50069/908624174.py:25: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(self.data[ticker]['Close'].iloc[-1])
# VaR 95% confidence: $502.48
# CVaR: $367.38
