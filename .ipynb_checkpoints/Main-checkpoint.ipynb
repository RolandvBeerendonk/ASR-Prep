# %%
if __name__ == "__main__":
    # %run ASRmodel.ipynb
    # %run ASRView.ipynb
    # %run ASRcontroller.ipynb
    
    model = ASRModel()
    view = ASRView()
    controller = ASRController(model, view)

    controller.add_stock("AAPL", "Technology", "Equity", 10, 150)
    controller.add_stock("MSFT", "Technology", "Equity", 5, 280)
    controller.add_stock("JNJ", "Healthcare", "Equity", 8, 160)

    controller.load_data("2020-01-01")

    print(controller.show_current_price("AAPL"))
    print(controller.show_portfolio_value())
    print(controller.show_portfolio_weight('asset'))

    controller.show_portfolio_circle()
    controller.show_portfolio_summary('asset')
    controller.show_var_plot()
    controller.show_correlation_plot()
    controller.show_cumulative_return()

    controller.simulate_and_plot_stock_paths(n_plot_paths=10)
    controller.simulate_and_plot_portfolio_paths(mode='quantiles', n_plot_paths=100)
# Out:
#   File <string>:12
#     def add_stock(self, ticker, sector, asset_class, quantity, purchase_price):
#                                                                                ^
# IndentationError: unindent does not match any outer indentation level
# Traceback (most recent call last):
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[38], line 2
#     get_ipython().run_line_magic('run', 'ASRmodel.ipynb')
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2480 in run_line_magic
#     result = fn(*args, **kwargs)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/magics/execution.py:737 in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3005 in safe_execfile_ipy
#     result.raise_error()
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:306 in raise_error
#     raise self.error_before_exec
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3098 in _run_cell
#     transformed_cell = self.transform_cell(raw_cell)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3368 in transform_cell
#     cell = self.input_transformer_manager.transform_cell(raw_cell)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/inputtransformer2.py:662 in transform_cell
#     lines = self.do_token_transforms(lines)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/inputtransformer2.py:647 in do_token_transforms
#     changed, lines = self.do_one_token_transform(lines)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/inputtransformer2.py:627 in do_one_token_transform
#     tokens_by_line = make_tokens_by_line(lines)
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/inputtransformer2.py:535 in make_tokens_by_line
#     for token in tokenutil.generate_tokens_catch_errors(
#
#   File /opt/anaconda3/lib/python3.12/site-packages/IPython/utils/tokenutil.py:40 in generate_tokens_catch_errors
#     for token in tokenize.generate_tokens(readline):
#
#   File /opt/anaconda3/lib/python3.12/tokenize.py:580 in _generate_tokens_from_c_tokenizer
#     raise e from None
#
#   File /opt/anaconda3/lib/python3.12/tokenize.py:576 in _generate_tokens_from_c_tokenizer
#     for info in it:
#
#   File <string>:12
#     def add_stock(self, ticker, sector, asset_class, quantity, purchase_price):
#                                                                                ^
# IndentationError: unindent does not match any outer indentation level
